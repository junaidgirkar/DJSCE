# %%
import nltk

# %%
# !pip install stanza
# !pip install indic-nlp-library
# !pip install indic-nlp-datasets
# !pip install inltk
# !pip install spacy
# !pip install contractions
# !pip install word2number
# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('stopwords')
# nltk.download('indian')

# %%
from nltk.corpus import indian

nltk.corpus.indian.words("hindi.pos")
# Out:
# ['पूर्ण', 'प्रतिबंध', 'हटाओ', ':', 'इराक', 'संयुक्त', ...]

# %%
# !pip install stanfordnlp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting stanfordnlp
#   Downloading stanfordnlp-0.2.0-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from stanfordnlp) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from stanfordnlp) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from stanfordnlp) (2.25.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.8/dist-packages (from stanfordnlp) (3.19.6)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from stanfordnlp) (1.13.1+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.0.0->stanfordnlp) (4.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->stanfordnlp) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->stanfordnlp) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->stanfordnlp) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->stanfordnlp) (2022.12.7)
# Installing collected packages: stanfordnlp
# Successfully installed stanfordnlp-0.2.0

# %%
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory

from idatasets import load_devdas
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import spacy
import pandas as pd

import stanfordnlp
import requests
from bs4 import BeautifulSoup
import unicodedata
import contractions
from word2number import w2n
import re
import stanza

from inltk.inltk import setup
from inltk.inltk import tokenize
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
URL = "http://www.values.com/inspirational-quotes"
r = requests.get(URL)
text = r.content
text
# Out:
# b'<!DOCTYPE html>\n<html class="no-js" dir="ltr" lang="en-US">\n<head>\n  <meta charset="utf-8">\n  <meta http-equiv="content-type" content="text/html; charset=utf-8" />\n  <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n  <meta name="viewport" content="width=device-width,initial-scale=1.0" />\n  <title>Inspirational Quotes - Motivational Quotes - | The Foundation for a Better Life</title>\n<meta name="description" content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors.">\n<meta name="keywords" content="pass, it, on, passiton, values, kindness">\n<meta name="twitter:site_name" content="The Foundation for a Better Life">\n<meta name="twitter:site" content="@passiton_values">\n<meta name="twitter:card" content="summary">\n<meta name="twitter:description" content="Thank you for visiting.">\n<meta name="twitter:image" content="https://www.passiton.com/passiton_fbl.jpg">\n<meta property="og:url" content="https://www.passiton.com/inspirational-quotes">\n<meta property="og:site_name" content="The Foundation for a Better Life">\n<meta property="og:title" content="Welcome to PassItOn.com">\n<meta property="og:image" content="https://www.passiton.com/passiton_fbl.jpg">\n<meta property="og:description" content="Thank you for visiting.">\n<meta property="og:type" content="website">\n  <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">\n  <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">\n  <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">\n  <link rel="manifest" href="/site.webmanifest">\n  <link rel="mask-icon" href="/safari-pinned-tab.svg" color="#c8102e">\n  <meta name="msapplication-TileColor" content="#ffffff">\n  <meta name="theme-color" content="#ffffff">\n  <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" crossorigin="anonymous">\n  <link rel="stylesheet" href="/assets/application-38427720f61b811fb76e2b47842105c506beb1b4ead60816a63acbc3010e5090.css" data-turbo-track="reload" />\n  <meta name="csrf-param" content="authenticity_token" />\n<meta name="csrf-token" content="eLT0gBgtQRwO7_6RWNcdMCWomAScgr8hAlKHrOXLVd-V0qXWps2CP_b7tSap4w848Tvxe4gA_KNZ52bBSrjoCg" />\n  \n  <!-- Global site tag (gtag.js) - Google Analytics -->\n  <script async src="https://www.googletagmanager.com/gtag/js?id=UA-1179606-29"></script>\n  <script>\n    window.dataLayer = window.dataLayer || [];\n    function gtag(){dataLayer.push(arguments);}\n    gtag(\'js\', new Date());\n    gtag(\'config\', \'UA-1179606-29\');\n  </script>\n\n  <script>\n    window.fbAsyncInit = function() {\n      FB.init({\n        appId            : \'483774921971842\',\n        autoLogAppEvents : true,\n        xfbml            : true,\n        version          : \'v6.0\'\n      });\n    };\n  </script>\n  <script async defer src="https://connect.facebook.net/en_US/sdk.js"></script>\n  <meta property="fb:app_id" content="483774921971842" />\n  <link rel="alternate" type="application/rss+xml" title="RSS" href="https://www.passiton.com/inspirational-quotes.atom" />\n\n  <!-- Google Tag Manager -->\n  <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n  new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n  j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n  \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n  })(window,document,\'script\',\'dataLayer\',\'GTM-WGXT9QJ\');</script>\n  <!-- End Google Tag Manager -->\n</head>\n<body class=\'no-transition quotes_index\'>\n  <!-- Google Tag Manager (noscript) -->\n  <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-WGXT9QJ"\n  height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>\n  <!-- End Google Tag Manager (noscript) ...

# %%
# setup('en')
# stanfordnlp.download('hi')
# stanfordnlp.download('en')
# stanza.download('hi')
# stanza.download('en')

# %%
def remove_html(text):
    soup = BeautifulSoup(text, "lxml")
    text = soup.get_text()
    return str(text)


def remove_whitespace(text):
    text = " ".join(text.split())
    return text


def accented_to_ascii(text):
    try:
        text = unicode(text, "utf-8")
    except (TypeError, NameError):  # unicode is a default on python 3
        pass
    text = unicodedata.normalize("NFD", text)
    text = text.encode("ascii", "ignore")
    text = text.decode("utf-8")
    return str(text)


def expand_contractions(text):
    expanded_words = []
    for word in text.split():
        expanded_words.append(contractions.fix(word))
    expanded_text = " ".join(expanded_words)
    return expanded_text


def remove_special(text):
    text = text.split()
    text = " ".join(x for x in text if not x.isalnum())
    text = text.split()
    special_char_list = ["$", "@", "#", "&", "%"]
    text = " ".join([k for k in text if k not in special_char_list])
    text = " ".join(text.split())
    return text


def text_to_lowercase(text):
    text = text.lower()
    return text


def number_word_to_numeric(text):
    text = text.split()
    output = ""
    for i in text:
        try:
            res = w2n.word_to_num(i)
        except:
            res = i
        output += str(res) + " "
    output = output.rstrip()
    return output


def remove_number(text):
    res = " ".join([i for i in text if not i.isdigit()])
    return res


def remove_stop_words(text):
    stop = open("stopwords.txt")

    stop_words = []

    for x in stop:
        stop_words.append(x)


    stop_words = list(set(stop_words))

    word_tokens = word_tokenize(text)
    filtered_sentence = []

    for w in word_tokens:
        if w not in stop_words:
            filtered_sentence.append(w)

    filtered_sentence = " ".join(filtered_sentence)
    return filtered_sentence


def lemmatization(text):
    nlp = stanza.Pipeline(lang="en", processors="tokenize, pos, lemma")
    doc = nlp(text)
    parsed_text = {"word": [], "lemma": []}
    for sent in doc.sentences:
        for wrd in sent.words:
            parsed_text["word"].append(wrd.text)
            parsed_text["lemma"].append(wrd.lemma)
    return pd.DataFrame(parsed_text)


def tokenization(text):
    tokenized_text = tokenize(text, "en")
    return tokenized_text


def stemming(text):
    ps = PorterStemmer()
    text = text.split()
    output = ""
    for i in text:
        res = ps.stem(i)
        output += str(res) + " "
    return output


def text_normalization(text):
    factory = IndicNormalizerFactory()
    normalizer = factory.get_normalizer("en")
    text = normalizer.normalize(text)
    return text


def pos(text):
    nlp = stanza.Pipeline(lang="en", processors="tokenize, pos, lemma")
    doc = nlp(text)
    parsed_text = {"word": [], "upos": [], "xpos": []}
    for sent in doc.sentences:
        for wrd in sent.words:
            parsed_text["word"].append(wrd.text)
            parsed_text["upos"].append(wrd.upos)
            parsed_text["xpos"].append(wrd.xpos)
    return pd.DataFrame(parsed_text)

# %%
output1 = remove_html(text)
output1
# Out:
# "\n\n\n\n\n\nInspirational Quotes - Motivational Quotes - | The Foundation for a Better Life\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n    window.dataLayer = window.dataLayer || [];\n    function gtag(){dataLayer.push(arguments);}\n    gtag('js', new Date());\n    gtag('config', 'UA-1179606-29');\n  \n\n    window.fbAsyncInit = function() {\n      FB.init({\n        appId            : '483774921971842',\n        autoLogAppEvents : true,\n        xfbml            : true,\n        version          : 'v6.0'\n      });\n    };\n  \n\n\n\n\n(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':\n  new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],\n  j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=\n  'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);\n  })(window,document,'script','dataLayer','GTM-WGXT9QJ');\n\n\n\n\n\n\n\n\n\n\n\n\n\n\ntoggle navigation\n\n\n\nQuotes\nVideos \n\nOfficial Pass It On® Videos\nArtCenter College of Design PSAs\n\n\nBillboards \n\nOfficial Billboards\nIs In You® Billboards\nCreate Your Own Billboard\n\n\nNewspapers\nRadio\nBlog\nSchools\n \n\nSpanish | Español\nPortuguese | Português\nChinese | 中文\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nGet our FREE daily quote emails!\nGet a daily inspirational quote in your inbox each weekday! Enter your email below to subscribe.\n\n\n\n          // Define function so that we can call it again later if we need to reset it\n          // This executes reCAPTCHA and then calls our callback.\n          function executeRecaptchaForSignup() {\n            grecaptcha.ready(function() {\n              grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'}).then(function(token) {\n                setInputWithRecaptchaResponseTokenForSignup('g-recaptcha-response-data-signup', token)\n              });\n            });\n          };\n          // Invoke immediately\n          executeRecaptchaForSignup()\n\n          // Async variant so you can await this function from another async function (no need for\n          // an explicit callback function then!)\n          // Returns a Promise that resolves with the response token.\n          async function executeRecaptchaForSignupAsync() {\n            return new Promise((resolve, reject) => {\n             grecaptcha.ready(async function() {\n                resolve(await grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'}))\n              });\n            })\n          };\n\n                    var setInputWithRecaptchaResponseTokenForSignup = function(id, token) {\n            var element = document.getElementById(id);\n            element.value = token;\n          }\n\n        \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nINSPIRATIONAL QUOTES\nFind the perfect quote... and Pass It On®\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLEADERSHIP\n\n\n\nLEADERSHIP\n\n\n\nLEADERSHIP\n\n\n\nLEADERSHIP\n\n\n\nLEADERSHIP\n\n\n\nLOVE\n\n\n\nLOVE\n\n\n\nLOVE\n\n\n\nLOVE\n\n\n\nLOVE\n\n\n\nLISTENING\n\n\n\nLISTENING\n\n\n\nLISTENING\n\n\n\nLISTENING\n\n\n\nLISTENING\n\n\n\nSTEWARDSHIP\n\n\n\nSTEWARDSHIP\n\n\n\nSTEWARDSHIP\n\n\n\nSTEWARDSHIP\n\n\n\nSTEWARDSHIP\n\n\n\nRESILIENCE\n\n\n\nRESILIENCE\n\n\n\nRESILIENCE\n\n\n\nRESILIENCE\n\n\n\nRESILIENCE\n\n\n\nEXPLORING\n\n\n\nEXPLORING\n\n\n\nEXPLORING\n\n\n\nEXPLORING\n\n\n\nEXPLORING\n\n\n\nKINDNESS\n\n\n\nKINDNESS\n\n\n\nKINDNESS\n\n\n\n\n\nWe publish our quotes and other inspirational stories on Facebook. Please 'like' our page to get daily inspiration.\nFoundation for A Better Life\n\n\n\n\n\n\n\n  1\n\n\n2\n\n\n3\n\n\n4\n\n\n5\n\n…\n\nNext ›\n\n\nLast »\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFollow us on social\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAbout Us\n\nAbout The Foundation for a Better Life\nFAQs\nFoundation Recognition\nContact Us\n\n\n\nBe Inspired\n\nTeaching Values\nInspirational Quotations\nPass It On® Videos\nArtCenter College of Design PSAs\nFree Newspap ...

# %%
output2 = remove_whitespace(output1)
output2
# Out:
# "Inspirational Quotes - Motivational Quotes - | The Foundation for a Better Life window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'UA-1179606-29'); window.fbAsyncInit = function() { FB.init({ appId : '483774921971842', autoLogAppEvents : true, xfbml : true, version : 'v6.0' }); }; (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-WGXT9QJ'); toggle navigation Quotes Videos Official Pass It On® Videos ArtCenter College of Design PSAs Billboards Official Billboards Is In You® Billboards Create Your Own Billboard Newspapers Radio Blog Schools Spanish | Español Portuguese | Português Chinese | 中文 Get our FREE daily quote emails! Get a daily inspirational quote in your inbox each weekday! Enter your email below to subscribe. // Define function so that we can call it again later if we need to reset it // This executes reCAPTCHA and then calls our callback. function executeRecaptchaForSignup() { grecaptcha.ready(function() { grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'}).then(function(token) { setInputWithRecaptchaResponseTokenForSignup('g-recaptcha-response-data-signup', token) }); }); }; // Invoke immediately executeRecaptchaForSignup() // Async variant so you can await this function from another async function (no need for // an explicit callback function then!) // Returns a Promise that resolves with the response token. async function executeRecaptchaForSignupAsync() { return new Promise((resolve, reject) => { grecaptcha.ready(async function() { resolve(await grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'})) }); }) }; var setInputWithRecaptchaResponseTokenForSignup = function(id, token) { var element = document.getElementById(id); element.value = token; } INSPIRATIONAL QUOTES Find the perfect quote... and Pass It On® LEADERSHIP LEADERSHIP LEADERSHIP LEADERSHIP LEADERSHIP LOVE LOVE LOVE LOVE LOVE LISTENING LISTENING LISTENING LISTENING LISTENING STEWARDSHIP STEWARDSHIP STEWARDSHIP STEWARDSHIP STEWARDSHIP RESILIENCE RESILIENCE RESILIENCE RESILIENCE RESILIENCE EXPLORING EXPLORING EXPLORING EXPLORING EXPLORING KINDNESS KINDNESS KINDNESS We publish our quotes and other inspirational stories on Facebook. Please 'like' our page to get daily inspiration. Foundation for A Better Life 1 2 3 4 5 … Next › Last » Follow us on social About Us About The Foundation for a Better Life FAQs Foundation Recognition Contact Us Be Inspired Teaching Values Inspirational Quotations Pass It On® Videos ArtCenter College of Design PSAs Free Newspaper Stories Who's Your Hero Stories Official Billboard Campaign Create Your Own Billboard Radio Ads Pass It On® Blog Podcasts Send an Ecard For Schools Free Posters & DVD for Schools Downloads For Media Companies For Media Companies Broadcast Quality PSA Downloads Pass It On Radio Ads Live Reads Out of Home Materials VALUES.COM® is now PassItOn.com® ©2000-2023 The Foundation for a Better Life. Privacy Policy | Terms of Use LIKE US ON FACEBOOK FOR A DAILY DOSE OF POSITIVITY Click the like button above to access our facebook page, then ‘like us’ to get a dose of positivity in your feed. No thanks DAILY INSPIRATION Get PassItOn’s daily inspirational quote & weekly blog in your inbox each weekday! Enter your email below to subscribe. It's free! // Define function so that we can call it again later if we need to reset it // This executes reCAPTCHA and then calls our callback. function executeRecaptchaForSignup() { grecaptcha.ready(function() { grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'}).then(function(token) { setInputWithRecaptchaResponseTokenForSignup('g-recaptc ...

# %%
output3 = accented_to_ascii(output2)
output3
# Out:
# "Inspirational Quotes - Motivational Quotes - | The Foundation for a Better Life window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'UA-1179606-29'); window.fbAsyncInit = function() { FB.init({ appId : '483774921971842', autoLogAppEvents : true, xfbml : true, version : 'v6.0' }); }; (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-WGXT9QJ'); toggle navigation Quotes Videos Official Pass It On Videos ArtCenter College of Design PSAs Billboards Official Billboards Is In You Billboards Create Your Own Billboard Newspapers Radio Blog Schools Spanish | Espanol Portuguese | Portugues Chinese |  Get our FREE daily quote emails! Get a daily inspirational quote in your inbox each weekday! Enter your email below to subscribe. // Define function so that we can call it again later if we need to reset it // This executes reCAPTCHA and then calls our callback. function executeRecaptchaForSignup() { grecaptcha.ready(function() { grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'}).then(function(token) { setInputWithRecaptchaResponseTokenForSignup('g-recaptcha-response-data-signup', token) }); }); }; // Invoke immediately executeRecaptchaForSignup() // Async variant so you can await this function from another async function (no need for // an explicit callback function then!) // Returns a Promise that resolves with the response token. async function executeRecaptchaForSignupAsync() { return new Promise((resolve, reject) => { grecaptcha.ready(async function() { resolve(await grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'})) }); }) }; var setInputWithRecaptchaResponseTokenForSignup = function(id, token) { var element = document.getElementById(id); element.value = token; } INSPIRATIONAL QUOTES Find the perfect quote... and Pass It On LEADERSHIP LEADERSHIP LEADERSHIP LEADERSHIP LEADERSHIP LOVE LOVE LOVE LOVE LOVE LISTENING LISTENING LISTENING LISTENING LISTENING STEWARDSHIP STEWARDSHIP STEWARDSHIP STEWARDSHIP STEWARDSHIP RESILIENCE RESILIENCE RESILIENCE RESILIENCE RESILIENCE EXPLORING EXPLORING EXPLORING EXPLORING EXPLORING KINDNESS KINDNESS KINDNESS We publish our quotes and other inspirational stories on Facebook. Please 'like' our page to get daily inspiration. Foundation for A Better Life 1 2 3 4 5  Next  Last  Follow us on social About Us About The Foundation for a Better Life FAQs Foundation Recognition Contact Us Be Inspired Teaching Values Inspirational Quotations Pass It On Videos ArtCenter College of Design PSAs Free Newspaper Stories Who's Your Hero Stories Official Billboard Campaign Create Your Own Billboard Radio Ads Pass It On Blog Podcasts Send an Ecard For Schools Free Posters & DVD for Schools Downloads For Media Companies For Media Companies Broadcast Quality PSA Downloads Pass It On Radio Ads Live Reads Out of Home Materials VALUES.COM is now PassItOn.com 2000-2023 The Foundation for a Better Life. Privacy Policy | Terms of Use LIKE US ON FACEBOOK FOR A DAILY DOSE OF POSITIVITY Click the like button above to access our facebook page, then like us to get a dose of positivity in your feed. No thanks DAILY INSPIRATION Get PassItOns daily inspirational quote & weekly blog in your inbox each weekday! Enter your email below to subscribe. It's free! // Define function so that we can call it again later if we need to reset it // This executes reCAPTCHA and then calls our callback. function executeRecaptchaForSignup() { grecaptcha.ready(function() { grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'}).then(function(token) { setInputWithRecaptchaResponseTokenForSignup('g-recaptcha-response-data ...

# %%
output4 = expand_contractions(output3)
output4
# Out:
# "Inspirational Quotes - Motivational Quotes - | The Foundation for a Better Life window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'UA-1179606-29'); window.fbAsyncInit = function() { FB.init({ appId : '483774921971842', autoLogAppEvents : true, xfbml : true, version : 'v6.0' }); }; (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-WGXT9QJ'); toggle navigation Quotes Videos Official Pass It On Videos ArtCenter College of Design PSAs Billboards Official Billboards Is In You Billboards Create Your Own Billboard Newspapers Radio Blog Schools Spanish | Espanol Portuguese | Portugues Chinese | Get our FREE daily quote emails! Get a daily inspirational quote in your inbox each weekday! Enter your email below to subscribe. // Define function so that we can call it again later if we need to reset it // This executes reCAPTCHA and then calls our callback. function executeRecaptchaForSignup() { grecaptcha.ready(function() { grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'}).then(function(token) { setInputWithRecaptchaResponseTokenForSignup('g-recaptcha-response-data-signup', token) }); }); }; // Invoke immediately executeRecaptchaForSignup() // Async variant so you can await this function from another async function (no need for // an explicit callback function then!) // Returns a Promise that resolves with the response token. async function executeRecaptchaForSignupAsync() { return new Promise((resolve, reject) => { grecaptcha.ready(async function() { resolve(await grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'})) }); }) }; var setInputWithRecaptchaResponseTokenForSignup = function(id, token) { var element = document.getElementById(id); element.value = token; } INSPIRATIONAL QUOTES Find the perfect quote... and Pass It On LEADERSHIP LEADERSHIP LEADERSHIP LEADERSHIP LEADERSHIP LOVE LOVE LOVE LOVE LOVE LISTENING LISTENING LISTENING LISTENING LISTENING STEWARDSHIP STEWARDSHIP STEWARDSHIP STEWARDSHIP STEWARDSHIP RESILIENCE RESILIENCE RESILIENCE RESILIENCE RESILIENCE EXPLORING EXPLORING EXPLORING EXPLORING EXPLORING KINDNESS KINDNESS KINDNESS We publish our quotes and other inspirational stories on Facebook. Please 'like' our page to get daily inspiration. Foundation for A Better Life 1 2 3 4 5 Next Last Follow us on social About Us About The Foundation for a Better Life FAQs Foundation Recognition Contact Us Be Inspired Teaching Values Inspirational Quotations Pass It On Videos ArtCenter College of Design PSAs Free Newspaper Stories Who is Your Hero Stories Official Billboard Campaign Create Your Own Billboard Radio Ads Pass It On Blog Podcasts Send an Ecard For Schools Free Posters & DVD for Schools Downloads For Media Companies For Media Companies Broadcast Quality PSA Downloads Pass It On Radio Ads Live Reads Out of Home Materials VALUES.COM is now PassItOn.com 2000-2023 The Foundation for a Better Life. Privacy Policy | Terms of Use LIKE US ON FACEBOOK FOR A DAILY DOSE OF POSITIVITY Click the like button above to access our facebook page, then like us to get a dose of positivity in your feed. No thanks DAILY INSPIRATION Get PassItOns daily inspirational quote & weekly blog in your inbox each weekday! Enter your email below to subscribe. It is free! // Define function so that we can call it again later if we need to reset it // This executes reCAPTCHA and then calls our callback. function executeRecaptchaForSignup() { grecaptcha.ready(function() { grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'}).then(function(token) { setInputWithRecaptchaResponseTokenForSignup('g-recaptcha-response-data-s ...

# %%
output5 = remove_special(output4)
output5
# Out:
# "- - | window.dataLayer = window.dataLayer || []; gtag(){dataLayer.push(arguments);} gtag('js', Date()); gtag('config', 'UA-1179606-29'); window.fbAsyncInit = function() { FB.init({ : '483774921971842', : true, : true, : 'v6.0' }); }; (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-WGXT9QJ'); | | | emails! weekday! subscribe. // // callback. executeRecaptchaForSignup() { grecaptcha.ready(function() { grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'}).then(function(token) { setInputWithRecaptchaResponseTokenForSignup('g-recaptcha-response-data-signup', token) }); }); }; // executeRecaptchaForSignup() // (no // then!) // token. executeRecaptchaForSignupAsync() { Promise((resolve, reject) => { grecaptcha.ready(async function() { resolve(await grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'})) }); }) }; = function(id, token) { = document.getElementById(id); element.value = token; } quote... Facebook. 'like' inspiration. VALUES.COM PassItOn.com 2000-2023 Life. | page, feed. weekday! subscribe. free! // // callback. executeRecaptchaForSignup() { grecaptcha.ready(function() { grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'}).then(function(token) { setInputWithRecaptchaResponseTokenForSignup('g-recaptcha-response-data-signup', token) }); }); }; // executeRecaptchaForSignup() // (no // then!) // token. executeRecaptchaForSignupAsync() { Promise((resolve, reject) => { grecaptcha.ready(async function() { resolve(await grecaptcha.execute('6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6', {action: 'signup'})) }); }) }; = function(id, token) { = document.getElementById(id); element.value = token; }"

# %%
output6 = text_to_lowercase(output2)
output6
# Out:
# "inspirational quotes - motivational quotes - | the foundation for a better life window.datalayer = window.datalayer || []; function gtag(){datalayer.push(arguments);} gtag('js', new date()); gtag('config', 'ua-1179606-29'); window.fbasyncinit = function() { fb.init({ appid : '483774921971842', autologappevents : true, xfbml : true, version : 'v6.0' }); }; (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new date().gettime(),event:'gtm.js'});var f=d.getelementsbytagname(s)[0], j=d.createelement(s),dl=l!='datalayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentnode.insertbefore(j,f); })(window,document,'script','datalayer','gtm-wgxt9qj'); toggle navigation quotes videos official pass it on® videos artcenter college of design psas billboards official billboards is in you® billboards create your own billboard newspapers radio blog schools spanish | español portuguese | português chinese | 中文 get our free daily quote emails! get a daily inspirational quote in your inbox each weekday! enter your email below to subscribe. // define function so that we can call it again later if we need to reset it // this executes recaptcha and then calls our callback. function executerecaptchaforsignup() { grecaptcha.ready(function() { grecaptcha.execute('6ldta8euaaaaacp3yt76yg8qwmdqkpdbkp1bchi6', {action: 'signup'}).then(function(token) { setinputwithrecaptcharesponsetokenforsignup('g-recaptcha-response-data-signup', token) }); }); }; // invoke immediately executerecaptchaforsignup() // async variant so you can await this function from another async function (no need for // an explicit callback function then!) // returns a promise that resolves with the response token. async function executerecaptchaforsignupasync() { return new promise((resolve, reject) => { grecaptcha.ready(async function() { resolve(await grecaptcha.execute('6ldta8euaaaaacp3yt76yg8qwmdqkpdbkp1bchi6', {action: 'signup'})) }); }) }; var setinputwithrecaptcharesponsetokenforsignup = function(id, token) { var element = document.getelementbyid(id); element.value = token; } inspirational quotes find the perfect quote... and pass it on® leadership leadership leadership leadership leadership love love love love love listening listening listening listening listening stewardship stewardship stewardship stewardship stewardship resilience resilience resilience resilience resilience exploring exploring exploring exploring exploring kindness kindness kindness we publish our quotes and other inspirational stories on facebook. please 'like' our page to get daily inspiration. foundation for a better life 1 2 3 4 5 … next › last » follow us on social about us about the foundation for a better life faqs foundation recognition contact us be inspired teaching values inspirational quotations pass it on® videos artcenter college of design psas free newspaper stories who's your hero stories official billboard campaign create your own billboard radio ads pass it on® blog podcasts send an ecard for schools free posters & dvd for schools downloads for media companies for media companies broadcast quality psa downloads pass it on radio ads live reads out of home materials values.com® is now passiton.com® ©2000-2023 the foundation for a better life. privacy policy | terms of use like us on facebook for a daily dose of positivity click the like button above to access our facebook page, then ‘like us’ to get a dose of positivity in your feed. no thanks daily inspiration get passiton’s daily inspirational quote & weekly blog in your inbox each weekday! enter your email below to subscribe. it's free! // define function so that we can call it again later if we need to reset it // this executes recaptcha and then calls our callback. function executerecaptchaforsignup() { grecaptcha.ready(function() { grecaptcha.execute('6ldta8euaaaaacp3yt76yg8qwmdqkpdbkp1bchi6', {action: 'signup'}).then(function(token) { setinputwithrecaptcharesponsetokenforsignup('g-recaptc ...

# %%
output7 = number_word_to_numeric(output6)
output7
# Out:
# "inspirational quotes - motivational quotes - | the foundation for a better life window.datalayer = window.datalayer || []; function gtag(){datalayer.push(arguments);} gtag('js', new date()); gtag('config', 'ua-1179606-29'); window.fbasyncinit = function() { fb.init({ appid : '483774921971842', autologappevents : true, xfbml : true, version : 'v6.0' }); }; (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new date().gettime(),event:'gtm.js'});var f=d.getelementsbytagname(s)[0], j=d.createelement(s),dl=l!='datalayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentnode.insertbefore(j,f); })(window,document,'script','datalayer','gtm-wgxt9qj'); toggle navigation quotes videos official pass it on® videos artcenter college of design psas billboards official billboards is in you® billboards create your own billboard newspapers radio blog schools spanish | español portuguese | português chinese | 中文 get our free daily quote emails! get a daily inspirational quote in your inbox each weekday! enter your email below to subscribe. // define function so that we can call it again later if we need to reset it // this executes recaptcha and then calls our callback. function executerecaptchaforsignup() { grecaptcha.ready(function() { grecaptcha.execute('6ldta8euaaaaacp3yt76yg8qwmdqkpdbkp1bchi6', {action: 'signup'}).then(function(token) { setinputwithrecaptcharesponsetokenforsignup('g-recaptcha-response-data-signup', token) }); }); }; // invoke immediately executerecaptchaforsignup() // async variant so you can await this function from another async function (no need for // an explicit callback function then!) // returns a promise that resolves with the response token. async function executerecaptchaforsignupasync() { return new promise((resolve, reject) => { grecaptcha.ready(async function() { resolve(await grecaptcha.execute('6ldta8euaaaaacp3yt76yg8qwmdqkpdbkp1bchi6', {action: 'signup'})) }); }) }; var setinputwithrecaptcharesponsetokenforsignup = function(id, token) { var element = document.getelementbyid(id); element.value = token; } inspirational quotes find the perfect quote... and pass it on® leadership leadership leadership leadership leadership love love love love love listening listening listening listening listening stewardship stewardship stewardship stewardship stewardship resilience resilience resilience resilience resilience exploring exploring exploring exploring exploring kindness kindness kindness we publish our quotes and other inspirational stories on facebook. please 'like' our page to get daily inspiration. foundation for a better life 1 2 3 4 5 … next › last » follow us on social about us about the foundation for a better life faqs foundation recognition contact us be inspired teaching values inspirational quotations pass it on® videos artcenter college of design psas free newspaper stories who's your hero stories official billboard campaign create your own billboard radio ads pass it on® blog podcasts send an ecard for schools free posters & dvd for schools downloads for media companies for media companies broadcast quality psa downloads pass it on radio ads live reads out of home materials values.com® is now passiton.com® ©2000-2023 the foundation for a better life. privacy policy | terms of use like us on facebook for a daily dose of positivity click the like button above to access our facebook page, then ‘like us’ to get a dose of positivity in your feed. no thanks daily inspiration get passiton’s daily inspirational quote & weekly blog in your inbox each weekday! enter your email below to subscribe. it's free! // define function so that we can call it again later if we need to reset it // this executes recaptcha and then calls our callback. function executerecaptchaforsignup() { grecaptcha.ready(function() { grecaptcha.execute('6ldta8euaaaaacp3yt76yg8qwmdqkpdbkp1bchi6', {action: 'signup'}).then(function(token) { setinputwithrecaptcharesponsetokenforsignup('g-recaptc ...

# %%
output8 = remove_number(output7)
output8
# Out:
# "i n s p i r a t i o n a l   q u o t e s   -   m o t i v a t i o n a l   q u o t e s   -   |   t h e   f o u n d a t i o n   f o r   a   b e t t e r   l i f e   w i n d o w . d a t a l a y e r   =   w i n d o w . d a t a l a y e r   | |   [ ] ;   f u n c t i o n   g t a g ( ) { d a t a l a y e r . p u s h ( a r g u m e n t s ) ; }   g t a g ( ' j s ' ,   n e w   d a t e ( ) ) ;   g t a g ( ' c o n f i g ' ,   ' u a - - ' ) ;   w i n d o w . f b a s y n c i n i t   =   f u n c t i o n ( )   {   f b . i n i t ( {   a p p i d   :   ' ' ,   a u t o l o g a p p e v e n t s   :   t r u e ,   x f b m l   :   t r u e ,   v e r s i o n   :   ' v . '   } ) ;   } ;   ( f u n c t i o n ( w , d , s , l , i ) { w [ l ] = w [ l ] | | [ ] ; w [ l ] . p u s h ( { ' g t m . s t a r t ' :   n e w   d a t e ( ) . g e t t i m e ( ) , e v e n t : ' g t m . j s ' } ) ; v a r   f = d . g e t e l e m e n t s b y t a g n a m e ( s ) [ ] ,   j = d . c r e a t e e l e m e n t ( s ) , d l = l ! = ' d a t a l a y e r ' ? ' & l = ' + l : ' ' ; j . a s y n c = t r u e ; j . s r c =   ' h t t p s : / / w w w . g o o g l e t a g m a n a g e r . c o m / g t m . j s ? i d = ' + i + d l ; f . p a r e n t n o d e . i n s e r t b e f o r e ( j , f ) ;   } ) ( w i n d o w , d o c u m e n t , ' s c r i p t ' , ' d a t a l a y e r ' , ' g t m - w g x t q j ' ) ;   t o g g l e   n a v i g a t i o n   q u o t e s   v i d e o s   o f f i c i a l   p a s s   i t   o n ®   v i d e o s   a r t c e n t e r   c o l l e g e   o f   d e s i g n   p s a s   b i l l b o a r d s   o f f i c i a l   b i l l b o a r d s   i s   i n   y o u ®   b i l l b o a r d s   c r e a t e   y o u r   o w n   b i l l b o a r d   n e w s p a p e r s   r a d i o   b l o g   s c h o o l s   s p a n i s h   |   e s p a ñ o l   p o r t u g u e s e   |   p o r t u g u ê s   c h i n e s e   |   中 文   g e t   o u r   f r e e   d a i l y   q u o t e   e m a i l s !   g e t   a   d a i l y   i n s p i r a t i o n a l   q u o t e   i n   y o u r   i n b o x   e a c h   w e e k d a y !   e n t e r   y o u r   e m a i l   b e l o w   t o   s u b s c r i b e .   / /   d e f i n e   f u n c t i o n   s o   t h a t   w e   c a n   c a l l   i t   a g a i n   l a t e r   i f   w e   n e e d   t o   r e s e t   i t   / /   t h i s   e x e c u t e s   r e c a p t c h a   a n d   t h e n   c a l l s   o u r   c a l l b a c k .   f u n c t i o n   e x e c u t e r e c a p t c h a f o r s i g n u p ( )   {   g r e c a p t c h a . r e a d y ( f u n c t i o n ( )   {   g r e c a p t c h a . e x e c u t e ( ' l d t a e u a a a a a c p y t y g q w m d q k p d b k p b c h i ' ,   { a c t i o n :   ' s i g n u p ' } ) . t h e n ( f u n c t i o n ( t o k e n )   {   s e t i n p u t w i t h r e c a p t c h a r e s p o n s e t o k e n f o r s i g n u p ( ' g - r e c a p t c h a - r e s p o n s e - d a t a - s i g n u p ' ,   t o k e n )   } ) ;   } ) ;   } ;   / /   i n v o k e   i m m e d i a t e l y   e x e c u t e r e c a p t c h a f o r s i g n u p ( )   / /   a s y n c   v a r i a n t   s o   y o u   c a n   a w a i t   t h i s   f u n c t i o n   f r o m   a n o t h e r   a s y n c   f u n c t i o n   ( n o   n e e d   f o r   / /   a n   e x p l i c i t   c a l l b a c k   f u n c t i o n   t h e n ! )   / /   r e t u r n s   a   p r o m i s e   t h a t   r e s o l v e s   w i t h   t h e   r e s p o n s e   t o k e n .   a s y n c   f u n c t i o n   e x e c u t e r e c a p t c h a f o r s i g n u p a s y n c ( )   {   r e t u r n   n e w   p r o m i s e ( ( r e s o l v e ,   r e j e c t )   = >   {   g r e c a p t c h a . r e a d y ( a s y n c   f u n c t i o n ( )   {   r e s o l v e ( a w a i t   g r e c a p t c h a . e x e c u t e ( ' l d t a e u a a a a a c p y t y g q w m d q k p d b k p b c h i ' ,   { a c t i o n :   ' s i g n u p ' } ) )   } ) ;   } )   } ;   v a r   s e t i n p u t w i t h r e c a p t c h a r e s p o n s e t o k e n f o r s i g n u p   =   f u n c t i o n ( i d ,   t o k e n )   {   v a r   e ...

# %%
output9 = remove_stop_words(output2)
output9
# Out:
# "Inspirational Quotes - Motivational Quotes - | The Foundation for a Better Life window.dataLayer = window.dataLayer || [ ] ; function gtag ( ) { dataLayer.push ( arguments ) ; } gtag ( 'js ' , new Date ( ) ) ; gtag ( 'config ' , 'UA-1179606-29 ' ) ; window.fbAsyncInit = function ( ) { FB.init ( { appId : '483774921971842 ' , autoLogAppEvents : true , xfbml : true , version : 'v6.0 ' } ) ; } ; ( function ( w , d , s , l , i ) { w [ l ] =w [ l ] || [ ] ; w [ l ] .push ( { 'gtm.start ' : new Date ( ) .getTime ( ) , event : 'gtm.js ' } ) ; var f=d.getElementsByTagName ( s ) [ 0 ] , j=d.createElement ( s ) , dl=l ! ='dataLayer ' ? ' & l='+l : '' ; j.async=true ; j.src= 'https : //www.googletagmanager.com/gtm.js ? id='+i+dl ; f.parentNode.insertBefore ( j , f ) ; } ) ( window , document , 'script ' , 'dataLayer ' , 'GTM-WGXT9QJ ' ) ; toggle navigation Quotes Videos Official Pass It On® Videos ArtCenter College of Design PSAs Billboards Official Billboards Is In You® Billboards Create Your Own Billboard Newspapers Radio Blog Schools Spanish | Español Portuguese | Português Chinese | 中文 Get our FREE daily quote emails ! Get a daily inspirational quote in your inbox each weekday ! Enter your email below to subscribe . // Define function so that we can call it again later if we need to reset it // This executes reCAPTCHA and then calls our callback . function executeRecaptchaForSignup ( ) { grecaptcha.ready ( function ( ) { grecaptcha.execute ( '6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6 ' , { action : 'signup ' } ) .then ( function ( token ) { setInputWithRecaptchaResponseTokenForSignup ( ' g-recaptcha-response-data-signup ' , token ) } ) ; } ) ; } ; // Invoke immediately executeRecaptchaForSignup ( ) // Async variant so you can await this function from another async function ( no need for // an explicit callback function then ! ) // Returns a Promise that resolves with the response token . async function executeRecaptchaForSignupAsync ( ) { return new Promise ( ( resolve , reject ) = > { grecaptcha.ready ( async function ( ) { resolve ( await grecaptcha.execute ( '6Ldta8EUAAAAACp3yt76yG8QWMdQkpDBkP1bcHi6 ' , { action : 'signup ' } ) ) } ) ; } ) } ; var setInputWithRecaptchaResponseTokenForSignup = function ( id , token ) { var element = document.getElementById ( id ) ; element.value = token ; } INSPIRATIONAL QUOTES Find the perfect quote ... and Pass It On® LEADERSHIP LEADERSHIP LEADERSHIP LEADERSHIP LEADERSHIP LOVE LOVE LOVE LOVE LOVE LISTENING LISTENING LISTENING LISTENING LISTENING STEWARDSHIP STEWARDSHIP STEWARDSHIP STEWARDSHIP STEWARDSHIP RESILIENCE RESILIENCE RESILIENCE RESILIENCE RESILIENCE EXPLORING EXPLORING EXPLORING EXPLORING EXPLORING KINDNESS KINDNESS KINDNESS We publish our quotes and other inspirational stories on Facebook . Please 'like ' our page to get daily inspiration . Foundation for A Better Life 1 2 3 4 5 … Next › Last » Follow us on social About Us About The Foundation for a Better Life FAQs Foundation Recognition Contact Us Be Inspired Teaching Values Inspirational Quotations Pass It On® Videos ArtCenter College of Design PSAs Free Newspaper Stories Who 's Your Hero Stories Official Billboard Campaign Create Your Own Billboard Radio Ads Pass It On® Blog Podcasts Send an Ecard For Schools Free Posters & DVD for Schools Downloads For Media Companies For Media Companies Broadcast Quality PSA Downloads Pass It On Radio Ads Live Reads Out of Home Materials VALUES.COM® is now PassItOn.com® ©2000-2023 The Foundation for a Better Life . Privacy Policy | Terms of Use LIKE US ON FACEBOOK FOR A DAILY DOSE OF POSITIVITY Click the like button above to access our facebook page , then ‘ like us ’ to get a dose of positivity in your feed . No thanks DAILY INSPIRATION Get PassItOn ’ s daily inspirational quote & weekly blog in your inbox each weekday ! Enter your email below to subscribe . It 's free ! // Define function so that we can call it again later if we need to reset it // This executes reCAPTCHA and then calls our call ...

# %%
output10 = lemmatization(output9)
output10
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# | lemma     | combined |
# ========================
#
# INFO:stanza:Use device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
#               word          lemma
# 0    Inspirational  inspirational
# 1           Quotes          quote
# 2                -              -
# 3     Motivational   Motivational
# 4           Quotes          quote
# ..             ...            ...
# 915          token          token
# 916              ;              ;
# 917              }              }
# 918             No             no
# 919         thanks         thanks
#
# [920 rows x 2 columns]

# %%
# setup('en')
output11 = tokenization(output2)
output11
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-ddb7c139ae1a> in <module>
#       1 # setup('en')
# ----> 2 output11 = tokenization(output2)
#       3 output11
#
# <ipython-input-44-610609c77c1d> in tokenization(text)
#      96
#      97 def tokenization(text):
# ---> 98     tokenized_text = tokenize(text, "en")
#      99     return tokenized_text
#     100
#
# /usr/local/lib/python3.8/dist-packages/inltk/inltk.py in tokenize(input, language_code)
#      60 def tokenize(input: str, language_code: str):
#      61     check_input_language(language_code)
# ---> 62     tok = LanguageTokenizer(language_code)
#      63     output = tok.tokenizer(input)
#      64     return output
#
# /usr/local/lib/python3.8/dist-packages/inltk/tokenizer.py in __init__(self, lang)
#      12     def __init__(self, lang: str):
#      13         self.lang = lang
# ---> 14         self.base = EnglishTokenizer(lang) if lang == LanguageCodes.english else IndicTokenizer(lang)
#      15
#      16     def tokenizer(self, t: str) -> List[str]:
#
# /usr/local/lib/python3.8/dist-packages/inltk/tokenizer.py in __init__(self, lang)
#      34         with open(path / f'models/{lang}/vocab.pkl', 'rb') as f:
#      35             self.vocab = Vocab(pickle.load(f))
# ---> 36         self.tok = SpacyTokenizer(lang)
#      37
#      38     def tokenizer(self, t: str) -> List[str]:
#
# /usr/local/lib/python3.8/dist-packages/fastai/text/transform.py in __init__(self, lang)
#      23     "Wrapper around a spacy tokenizer to make it a `BaseTokenizer`."
#      24     def __init__(self, lang:str):
# ---> 25         self.tok = spacy.blank(lang, disable=["parser","tagger","ner"])
#      26
#      27     def tokenizer(self, t:str) -> List[str]:
#
# TypeError: blank() got an unexpected keyword argument 'disable'

# %%
output12 = stemming(output2)
output12
# Out:
# "inspir quot - motiv quot - | the foundat for a better life window.datalay = window.datalay || []; function gtag(){datalayer.push(arguments);} gtag('js', new date()); gtag('config', 'ua-1179606-29'); window.fbasyncinit = function() { fb.init({ appid : '483774921971842', autologappev : true, xfbml : true, version : 'v6.0' }); }; (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new date().gettime(),event:'gtm.js'});var f=d.getelementsbytagname(s)[0], j=d.createelement(s),dl=l!='datalayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentnode.insertbefore(j,f); })(window,document,'script','datalayer','gtm-wgxt9qj'); toggl navig quot video offici pass it on® video artcent colleg of design psa billboard offici billboard is in you® billboard creat your own billboard newspap radio blog school spanish | español portugues | portuguê chines | 中文 get our free daili quot emails! get a daili inspir quot in your inbox each weekday! enter your email below to subscribe. // defin function so that we can call it again later if we need to reset it // thi execut recaptcha and then call our callback. function executerecaptchaforsignup() { grecaptcha.ready(function() { grecaptcha.execute('6ldta8euaaaaacp3yt76yg8qwmdqkpdbkp1bchi6', {action: 'signup'}).then(function(token) { setinputwithrecaptcharesponsetokenforsignup('g-recaptcha-response-data-signup', token) }); }); }; // invok immedi executerecaptchaforsignup() // async variant so you can await thi function from anoth async function (no need for // an explicit callback function then!) // return a promis that resolv with the respons token. async function executerecaptchaforsignupasync() { return new promise((resolve, reject) => { grecaptcha.ready(async function() { resolve(await grecaptcha.execute('6ldta8euaaaaacp3yt76yg8qwmdqkpdbkp1bchi6', {action: 'signup'})) }); }) }; var setinputwithrecaptcharesponsetokenforsignup = function(id, token) { var element = document.getelementbyid(id); element.valu = token; } inspir quot find the perfect quote... and pass it on® leadership leadership leadership leadership leadership love love love love love listen listen listen listen listen stewardship stewardship stewardship stewardship stewardship resili resili resili resili resili explor explor explor explor explor kind kind kind we publish our quot and other inspir stori on facebook. pleas 'like' our page to get daili inspiration. foundat for a better life 1 2 3 4 5 … next › last » follow us on social about us about the foundat for a better life faq foundat recognit contact us be inspir teach valu inspir quotat pass it on® video artcent colleg of design psa free newspap stori who' your hero stori offici billboard campaign creat your own billboard radio ad pass it on® blog podcast send an ecard for school free poster & dvd for school download for media compani for media compani broadcast qualiti psa download pass it on radio ad live read out of home materi values.com® is now passiton.com® ©2000-2023 the foundat for a better life. privaci polici | term of use like us on facebook for a daili dose of posit click the like button abov to access our facebook page, then ‘like us’ to get a dose of posit in your feed. no thank daili inspir get passiton’ daili inspir quot & weekli blog in your inbox each weekday! enter your email below to subscribe. it' free! // defin function so that we can call it again later if we need to reset it // thi execut recaptcha and then call our callback. function executerecaptchaforsignup() { grecaptcha.ready(function() { grecaptcha.execute('6ldta8euaaaaacp3yt76yg8qwmdqkpdbkp1bchi6', {action: 'signup'}).then(function(token) { setinputwithrecaptcharesponsetokenforsignup('g-recaptcha-response-data-signup', token) }); }); }; // invok immedi executerecaptchaforsignup() // async variant so you can await thi function from anoth async function (no need for // an explicit callback function then!) // return a promis that resolv with the respons token. ...

# %%
output13 = text_normalization(output12)
output13
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-452377dca09d> in <module>
# ----> 1 output13 = text_normalization(output12)
#       2 output13
#
# <ipython-input-44-610609c77c1d> in text_normalization(text)
#     112 def text_normalization(text):
#     113     factory = IndicNormalizerFactory()
# --> 114     normalizer = factory.get_normalizer("en")
#     115     text = normalizer.normalize(text)
#     116     return text
#
# /usr/local/lib/python3.8/dist-packages/indicnlp/normalize/indic_normalize.py in get_normalizer(self, language, **kwargs)
#     930             normalizer=TeluguNormalizer(lang=language, **kwargs)
#     931         else:
# --> 932             normalizer=BaseNormalizer(lang=language, **kwargs)
#     933
#     934         return normalizer
#
# /usr/local/lib/python3.8/dist-packages/indicnlp/normalize/indic_normalize.py in __init__(self, lang, remove_nuktas, nasals_mode, do_normalize_chandras, do_normalize_vowel_ending)
#      88         self.do_normalize_vowel_ending=do_normalize_vowel_ending
#      89
# ---> 90         self._init_normalize_chandras()
#      91         self._init_normalize_nasals()
#      92         self._init_normalize_vowel_ending()
#
# /usr/local/lib/python3.8/dist-packages/indicnlp/normalize/indic_normalize.py in _init_normalize_chandras(self)
#     116             ]
#     117
# --> 118         self.chandra_substitutions =  [
#     119                 (langinfo.offset_to_char(x[0],self.lang), langinfo.offset_to_char(x[1],self.lang))
#     120                     for x in substitution_offsets ]
#
# /usr/local/lib/python3.8/dist-packages/indicnlp/normalize/indic_normalize.py in <listcomp>(.0)
#     117
#     118         self.chandra_substitutions =  [
# --> 119                 (langinfo.offset_to_char(x[0],self.lang), langinfo.offset_to_char(x[1],self.lang))
#     120                     for x in substitution_offsets ]
#     121
#
# /usr/local/lib/python3.8/dist-packages/indicnlp/langinfo.py in offset_to_char(c, lang)
#      89     Applicable to Brahmi derived Indic scripts
#      90     """
# ---> 91     return chr(c+SCRIPT_RANGES[lang][0])
#      92
#      93 def in_coordinated_range(c_offset):
#
# KeyError: 'en'

# %%
output14 = pos(output13)
output14
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-bc4999fb9ac2> in <module>
# ----> 1 output14 = pos(output13)
#       2 output14
#
# NameError: name 'output13' is not defined
